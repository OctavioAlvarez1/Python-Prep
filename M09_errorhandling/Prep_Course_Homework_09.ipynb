# %% [markdown]
# ## Manejo de errores

# %% [markdown]
# 1) Con la clase creada en el módulo 7, tener en cuenta diferentes casos en que el código pudiera arrojar error. Por ejemplo, en la creación del objeto recibimos una lista de números enteros pero ¿qué pasa si se envía otro tipo de dato?

# %%
class FuncionesEspeciales:
    @staticmethod
    def es_primo(numero):
        if not isinstance(numero, int):
            raise ValueError("Error: El número debe ser un entero.")
        if numero < 2:
            return False
        for i in range(2, int(numero**0.5) + 1):
            if numero % i == 0:
                return False
        return True

    @staticmethod
    def valor_modal(lista):
        if not all(isinstance(elemento, int) for elemento in lista):
            raise ValueError("Error: La lista debe contener solo números enteros.")
        if not lista:
            raise ValueError("Error: La lista no puede estar vacía.")
        
        frecuencias = {}
        for elemento in lista:
            frecuencias[elemento] = frecuencias.get(elemento, 0) + 1

        modos = [key for key, value in frecuencias.items() if value == max(frecuencias.values())]
        return modos

    @staticmethod
    def convertir_grados(valor, medida_origen, medida_destino):
        unidades_validas = {"C", "F", "K"}
        tipos_numericos_validos = (int, float)
        
        if not (isinstance(valor, tipos_numericos_validos) and isinstance(medida_origen, str) and isinstance(medida_destino, str)):
            raise ValueError("Error: Los argumentos deben ser valores numéricos y las medidas deben ser cadenas.")
        if medida_origen not in unidades_validas or medida_destino not in unidades_validas:
            raise ValueError(f"Error: Las medidas deben ser una de las siguientes: {', '.join(unidades_validas)}.")


    @staticmethod
    def calcular_factorial(num):
        if not isinstance(num, int) or num < 0:
            raise ValueError("Error: El número debe ser un entero no negativo.")
        
        resultado = 1
        for i in range(1, num + 1):
            resultado *= i
        return resultado

try:
    funciones_especiales = FuncionesEspeciales()

    # Verificar primo
    print(funciones_especiales.es_primo(7))

    # Valor modal
    lista_valores = [1, 2, 2, 3, 4, 5, 5, 5]
    print(funciones_especiales.valor_modal(lista_valores))

    # Conversión de grados
    print(funciones_especiales.convertir_grados(25, "C", "F"))

    # Factorial
    print(funciones_especiales.calcular_factorial(5))
    
except ValueError as e:
    print(e)
# Out:
# True
# [5]
# None
# 120

# %% [markdown]
# 2) En la función que hace la conversión de grados, validar que los parámetros enviados sean los esperados, de no serlo, informar cuáles son los valores esperados.

# %%
class FuncionesEspeciales:

    @staticmethod
    def convertir_grados(valor, medida_origen, medida_destino):
        unidades_validas = {"C", "F", "K"}
        tipos_numericos_validos = (int, float)
        
        if not (isinstance(valor, tipos_numericos_validos) and isinstance(medida_origen, str) and isinstance(medida_destino, str)):
            raise ValueError("Error: Los argumentos deben ser valores numéricos y las medidas deben ser cadenas.")
        if medida_origen not in unidades_validas or medida_destino not in unidades_validas:
            raise ValueError(f"Error: Las medidas deben ser una de las siguientes: {', '.join(unidades_validas)}.")

        resultado = None  

        if medida_origen == "C" and medida_destino == "F":
            resultado = valor * 9/5 + 32
        elif medida_origen == "C" and medida_destino == "K":
            resultado = valor + 273.15
        elif medida_origen == "F" and medida_destino == "C":
            resultado = (valor - 32) * 5/9
        elif medida_origen == "F" and medida_destino == "K":
            resultado = (valor + 459.67) * 5/9
        elif medida_origen == "K" and medida_destino == "C":
            resultado = valor - 273.15
        elif medida_origen == "K" and medida_destino == "F":
            resultado = valor * 9/5 - 459.67
        else:
            raise ValueError("Error: Las medidas deben ser 'C', 'F' o 'K'.")  

        return resultado

    @staticmethod
    def calcular_factorial(num):
        # Código existente...

    # Ejemplo de uso
    try:
        funciones_especiales = FuncionesEspeciales()

        # Conversión de grados
        print(funciones_especiales.convertir_grados(25, "C", "F"))
        print(funciones_especiales.convertir_grados(25, "C", "Z"))  
    except ValueError as e:
        print(e)
# Out:
#   Cell In[9], line 38
#     try:
#     ^
# IndentationError: expected an indented block after function definition on line 34

# %% [markdown]
# 3) Importar el modulo "unittest" y crear los siguientes casos de pruebas sobre la clase utilizada en el punto 2<br>
# Creacion del objeto incorrecta<br>
# Creacion correcta del objeto<br>
# Metodo valor_modal()<br>
#
# Se puede usar "raise ValueError()" en la creación de la clase para verificar el error. Investigar sobre esta funcionalidad.

# %%
import unittest

class TestFuncionesEspeciales(unittest.TestCase):
    def test_creacion_objeto_incorrecta(self):
        with self.assertRaises(ValueError):
            funciones_especiales = FuncionesEspeciales()

    def test_creacion_objeto_correcta(self):
        try:
            funciones_especiales = FuncionesEspeciales()
        except ValueError:
            self.fail("No debería haber lanzado una excepción durante la creación del objeto.")

    def test_valor_modal(self):
        funciones_especiales = FuncionesEspeciales()

        # Caso de prueba 1: Lista con valores enteros
        lista_valores = [1, 2, 2, 3, 4, 5, 5, 5]
        resultado = funciones_especiales.valor_modal(lista_valores)
        self.assertEqual(resultado, [5], "El valor modal debería ser [5] para la lista dada.")

        # Caso de prueba 2: Lista vacía
        lista_vacia = []
        with self.assertRaises(ValueError):
            funciones_especiales.valor_modal(lista_vacia)

        # Caso de prueba 3: Lista con valores no enteros
        lista_no_enteros = ["a", 2, 3.5, "b"]
        with self.assertRaises(ValueError):
            funciones_especiales.valor_modal(lista_no_enteros)

if __name__ == '__main__':
    unittest.main()
# Out:
# usage: ipykernel_launcher.py [-h] [-v] [-q] [--locals] [-f] [-c] [-b]
#                              [-k TESTNAMEPATTERNS]
#                              [tests ...]
# ipykernel_launcher.py: error: argument -f/--failfast: ignored explicit argument 'c:\\Users\\Pc\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-14200AZr9i05bc65R.json'
# ---------------------------------------------------------------------------
# ArgumentError                             Traceback (most recent call last)
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\argparse.py:1859, in ArgumentParser.parse_known_args(self, args, namespace)
#    1858 try:
# -> 1859     namespace, args = self._parse_known_args(args, namespace)
#    1860 except ArgumentError:
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\argparse.py:2068, in ArgumentParser._parse_known_args(self, arg_strings, namespace)
#    2067     # consume the next optional and any arguments for it
# -> 2068     start_index = consume_optional(start_index)
#    2070 # consume any positionals following the last Optional
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\argparse.py:1990, in ArgumentParser._parse_known_args.<locals>.consume_optional(start_index)
#    1989         msg = _('ignored explicit argument %r')
# -> 1990         raise ArgumentError(action, msg % explicit_arg)
#    1992 # if there is no explicit argument, try to match the
#    1993 # optional's string arguments with the following strings
#    1994 # if successful, exit the loop
#    1995 else:
#
# ArgumentError: argument -f/--failfast: ignored explicit argument 'c:\\Users\\Pc\\AppData\\Roaming\\jupyter\\runtime\\kernel-v2-14200AZr9i05bc65R.json'
#
# During handling of the above exception, another exception occurred:
#
# SystemExit                                Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# Cell In[10], line 33
#      32 if __name__ == '__main__':
# ---> 33     unittest.main()
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\unittest\main.py:100, in TestProgram.__init__(self, module, defaultTest, argv, testRunner, testLoader, exit, verbosity, failfast, catchbreak, buffer, warnings, tb_locals)
#      99 self.progName = os.path.basename(argv[0])
# --> 100 self.parseArgs(argv)
#     101 self.runTests()
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\unittest\main.py:133, in TestProgram.parseArgs(self, argv)
#     132 else:
# --> 133     self._main_parser.parse_args(argv[1:], self)
#     135 if self.tests:
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\argparse.py:1826, in ArgumentParser.parse_args(self, args, namespace)
#    1825 def parse_args(self, args=None, namespace=None):
# -> 1826     args, argv = self.parse_known_args(args, namespace)
#    1827     if argv:
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\argparse.py:1862, in ArgumentParser.parse_known_args(self, args, namespace)
#    1861         err = _sys.exc_info()[1]
# -> 1862         self.error(str(err))
#    1863 else:
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\argparse.py:2583, in ArgumentParser.error(self, message)
#    2582 args = {'prog': self.prog, 'message': message}
# -> 2583 self.exit(2, _('%(prog)s: error: %(message)s\n') % args)
#
# File c:\Users\Pc\AppData\Local\Programs\Python\Python310\lib\argparse.py:2570, in ArgumentParser.exit(self, status, message)
#    2569     self._print_message(message, _sys.stderr)
# -> 2570 _sys.exit(status)
#
# SystemExit: 2
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\interactiveshell.py:2121, in InteractiveShell.showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2118 if exception_only:
#    2119     stb = ['An exception has occurred, use %tb to see '
#    2120            'the full traceback.\n']
# -> 2121     stb.extend(self.InteractiveTB.get_exception_only(etype,
#    2122                                                      value))
#    2123 else:
#    2125     def contains_exceptiongroup(val):
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py:710, in ListTB.get_exception_only(self, etype, value)
#     702 def get_exception_only(self, etype, value):
#     703     """Only print the exception type and message, without a traceback.
#     704
#     705     Parameters
#    (...)
#     708     value : exception value
#     709     """
# --> 710     return ListTB.structured_traceback(self, etype, value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py:568, in ListTB.structured_traceback(self, etype, evalue, etb, tb_offset, context)
#     565     chained_exc_ids.add(id(exception[1]))
#     566     chained_exceptions_tb_offset = 0
#     567     out_list = (
# --> 568         self.structured_traceback(
#     569             etype,
#     570             evalue,
#     571             (etb, chained_exc_ids),  # type: ignore
#     572             chained_exceptions_tb_offset,
#     573             context,
#     574         )
#     575         + chained_exception_message
#     576         + out_list)
#     578 return out_list
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py:1435, in AutoFormattedTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1433 else:
#    1434     self.tb = etb
# -> 1435 return FormattedTB.structured_traceback(
#    1436     self, etype, evalue, etb, tb_offset, number_of_lines_of_context
#    1437 )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py:1326, in FormattedTB.structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1323 mode = self.mode
#    1324 if mode in self.verbose_modes:
#    1325     # Verbose modes need a full traceback
# -> 1326     return VerboseTB.structured_traceback(
#    1327         self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1328     )
#    1329 elif mode == 'Minimal':
#    1330     return ListTB.get_exception_only(self, etype, value)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py:1173, in VerboseTB.structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1164 def structured_traceback(
#    1165     self,
#    1166     etype: type,
#    (...)
#    1170     number_of_lines_of_context: int = 5,
#    1171 ):
#    1172     """Return a nice text document describing the traceback."""
# -> 1173     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1174                                                            tb_offset)
#    1176     colors = self.Colors  # just a shorthand + quicker name lookup
#    1177     colorsnormal = colors.Normal  # used a lot
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py:1063, in VerboseTB.format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1060 assert isinstance(tb_offset, int)
#    1061 head = self.prepare_header(str(etype), self.long_header)
#    1062 records = (
# -> 1063     self.get_records(etb, number_of_lines_of_context, tb_offset) if etb else []
#    1064 )
#    1066 frames = []
#    1067 skipped = 0
#
# File ~\AppData\Roaming\Python\Python310\site-packages\IPython\core\ultratb.py:1131, in VerboseTB.get_records(self, etb, number_of_lines_of_context, tb_offset)
#    1129 while cf is not None:
#    1130     try:
# -> 1131         mod = inspect.getmodule(cf.tb_frame)
#    1132         if mod is not None:
#    1133             mod_name = mod.__name__
#
# AttributeError: 'tuple' object has no attribute 'tb_frame'

# %% [markdown]
# 4) Probar una creación incorrecta y visualizar la salida del "raise"

# %%
import unittest

class TestFuncionesEspeciales(unittest.TestCase):
    def test_creacion_objeto_incorrecta(self):
        with self.assertRaises(ValueError) as context:
            funciones_especiales = FuncionesEspeciales()

        print(f"Mensaje de la excepción: {context.exception}")

if __name__ == '__main__':
    unittest.main()

# %% [markdown]
# 6) Agregar casos de pruebas para el método verifica_primos() realizando el cambio en la clase, para que devuelva una lista de True o False en función de que el elemento en la posisicón sea o no primo

# %%
class FuncionesEspeciales:
    @staticmethod
    def es_primo(numero):
        if numero < 2:
            return False
        for i in range(2, int(numero**0.5) + 1):
            if numero % i == 0:
                return False
        return True

    @staticmethod
    def verifica_primos(lista):
        return [FuncionesEspeciales.es_primo(elemento) for elemento in lista]

class TestFuncionesEspeciales(unittest.TestCase):
    def test_verifica_primos_lista_vacia(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.verifica_primos([])
        self.assertEqual(resultado, [], "La lista de números primos debería ser vacía para una lista vacía.")

    def test_verifica_primos_lista_con_primos(self):
        funciones_especiales = FuncionesEspeciales()
        lista_con_primos = [2, 3, 5, 7, 11]
        resultado = funciones_especiales.verifica_primos(lista_con_primos)
        self.assertEqual(resultado, [True, True, True, True, True], "Todos los números en la lista son primos.")

    def test_verifica_primos_lista_sin_primos(self):
        funciones_especiales = FuncionesEspeciales()
        lista_sin_primos = [4, 6, 8, 9, 10]
        resultado = funciones_especiales.verifica_primos(lista_sin_primos)
        self.assertEqual(resultado, [False, False, False, False, False], "Ninguno de los números en la lista es primo.")

if __name__ == '__main__':
    unittest.main()

# %% [markdown]
# 7) Agregar casos de pruebas para el método conversion_grados()

# %%
class FuncionesEspeciales:
    @staticmethod
    def conversion_grados(valor, medida_origen, medida_destino):
        if medida_origen == "C" and medida_destino == "F":
            return valor * 9/5 + 32
        elif medida_origen == "C" and medida_destino == "K":
            return valor + 273.15
        elif medida_origen == "F" and medida_destino == "C":
            return (valor - 32) * 5/9
        elif medida_origen == "F" and medida_destino == "K":
            return (valor + 459.67) * 5/9
        elif medida_origen == "K" and medida_destino == "C":
            return valor - 273.15
        elif medida_origen == "K" and medida_destino == "F":
            return valor * 9/5 - 459.67
        else:
            return valor

# Casos de prueba para conversion_grados() en la clase TestFuncionesEspeciales
class TestFuncionesEspeciales(unittest.TestCase):
    def test_conversion_grados_celsius_a_fahrenheit(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.conversion_grados(0, "C", "F")
        self.assertEqual(resultado, 32, "La conversión de 0°C a Fahrenheit debería ser 32°F.")

    def test_conversion_grados_celsius_a_kelvin(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.conversion_grados(100, "C", "K")
        self.assertEqual(resultado, 373.15, "La conversión de 100°C a Kelvin debería ser 373.15K.")

    def test_conversion_grados_fahrenheit_a_celsius(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.conversion_grados(32, "F", "C")
        self.assertEqual(resultado, 0, "La conversión de 32°F a Celsius debería ser 0°C.")

    def test_conversion_grados_fahrenheit_a_kelvin(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.conversion_grados(212, "F", "K")
        self.assertEqual(resultado, 373.15, "La conversión de 212°F a Kelvin debería ser 373.15K.")

    def test_conversion_grados_kelvin_a_celsius(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.conversion_grados(273.15, "K", "C")
        self.assertEqual(resultado, 0, "La conversión de 273.15K a Celsius debería ser 0°C.")

    def test_conversion_grados_kelvin_a_fahrenheit(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.conversion_grados(373.15, "K", "F")
        self.assertEqual(resultado, 32, "La conversión de 373.15K a Fahrenheit debería ser 32°F.")

if __name__ == '__main__':
    unittest.main()

# %% [markdown]
# 8) Agregar casos de pruebas para el método factorial()

# %%
class FuncionesEspeciales:
    @staticmethod
    def factorial(num):
        if isinstance(num, int) and num >= 0:
            resultado = 1
            for i in range(1, num + 1):
                resultado *= i
            return resultado
        else:
            return None

# Casos de prueba para factorial() en la clase TestFuncionesEspeciales
class TestFuncionesEspeciales(unittest.TestCase):
    def test_factorial_numero_cero(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.factorial(0)
        self.assertEqual(resultado, 1, "El factorial de 0 debería ser 1.")

    def test_factorial_numero_positivo(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.factorial(5)
        self.assertEqual(resultado, 120, "El factorial de 5 debería ser 120.")

    def test_factorial_numero_negativo(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.factorial(-3)
        self.assertIsNone(resultado, "El factorial de un número negativo no está definido.")

    def test_factorial_numero_no_entero(self):
        funciones_especiales = FuncionesEspeciales()
        resultado = funciones_especiales.factorial(3.5)
        self.assertIsNone(resultado, "El factorial de un número no entero no está definido.")

if __name__ == '__main__':
    unittest.main()
